# %% [markdown]
# <a href="https://colab.research.google.com/github/Patricks-a11y/Projrct-1/blob/main/Markdown_Docummentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This *is* **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#   print(item)
# ```

# %% [markdown]
# ![Patrick Sabas. Passport-size Photo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Google Search](https://www.google.com)

# %% [markdown]
# 1.   First
# 2.   Second

# %% [markdown]
# Indent
#
#
# > Indented block
#
#
# Indented

# %% [markdown]
# $ax^2 + bx + c = 0$

# %% [markdown]
# $x_1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$

# %% [markdown]
# $$x_1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$$
